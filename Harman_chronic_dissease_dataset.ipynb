# %% [markdown]
# ## Chronic Kidney Dsease Pridiction

# %% [markdown]
# ## By:Harmandeep Kaur

# %% [markdown]
# GU-2024-3458

# %% [markdown]
# B Tech CSE 4A

# %% [markdown]
# Course: Machine Learning

# %% [markdown]
# Assignment1

# %% [markdown]
# ### Dataset Information

# %% [markdown]
# Dataset Name: Chronic Kidney Dsease

# %% [markdown]
# Dataset Link:https://www.kaggle.com/datasets/usmanshafeeqdit/chronic-kidney-dsease-data

# %% [markdown]
# ## IMPORTING DATASET

# %%
import kagglehub

path = kagglehub.dataset_download("mansoordaku/ckdisease")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\Administrator\.cache\kagglehub\datasets\mansoordaku\ckdisease\versions\1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## LODING DATASET

# %%
import pandas as pd
df = pd.read_csv("Chronic_Kidney_Dsease_data.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("Chronic_Kidney_Dsease_data.csv")
#       3 df.head()
#
# ...

# %% [markdown]
# ## DATA UNDERSTANDING

# %%
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.shape
#
# NameError: name 'df' is not defined

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df.describe()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Checking Missing Values

# %%
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df.isnull().sum()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Handling Missing Values

# %%
for col in df.select_dtypes(include=np.number).columns:
    df[col].fillna(df[col].median(), inplace=True)

for col in df.select_dtypes(include=object).columns:
    df[col].fillna(df[col].mode()[0], inplace=True)

df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 for col in df.select_dtypes(include=np.number).columns:
#       2     df[col].fillna(df[col].median(), inplace=True)
#       4 for col in df.select_dtypes(include=object).columns:
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### Encoding Categorical variables

# %%
# Convert categorical columns into numerical
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for col in df.select_dtypes(include='object').columns:
    df[col] = le.fit_transform(df[col])

df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 6
#       2 from sklearn.preprocessing import LabelEncoder
#       4 le = LabelEncoder()
# ----> 6 for col in df.select_dtypes(include='object').columns:
#       7     df[col] = le.fit_transform(df[col])
#       9 df.head()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Data Analysis & Visualization

# %% [markdown]
# ### Target Variable Distribution

# %%
df.columns = df.columns.str.strip()
print(df.columns)
plt.figure(figsize=(6,4))
sns.countplot(x='Diagnosis', data=df)
plt.title("CKD vs Non-CKD Count")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.columns = df.columns.str.strip()
#       2 print(df.columns)
#       3 plt.figure(figsize=(6,4))
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### Correlation Heatmap

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 plt.figure(figsize=(12,8))
# ----> 2 sns.heatmap(df.corr(), cmap='coolwarm')
#       3 plt.title("Correlation Heatmap")
#       4 plt.show()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### Age Distribution

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['Age'], bins=20, kde=True)
plt.title("Age Distribution")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 plt.figure(figsize=(6,4))
# ----> 2 sns.histplot(df['Age'], bins=20, kde=True)
#       3 plt.title("Age Distribution")
#       4 plt.show()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### Blood Pressure VS CKD

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x='Diagnosis', y='HemoglobinLevels', data=df)
plt.title("Hemoglobin Level vs CKD")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 plt.figure(figsize=(6,4))
# ----> 2 sns.boxplot(x='Diagnosis', y='HemoglobinLevels', data=df)
#       3 plt.title("Hemoglobin Level vs CKD")
#       4 plt.show()
#
# NameError: name 'df' is not defined
